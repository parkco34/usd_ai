# %% [markdown]
# # Import and global constants

# %%
from textwrap import dedent
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Global constants
NUM_CLASSES = 10
EPOCHS = 5
BATCH_SIZE = 64
VALIDATION_SPLIT = 0.10
STATE=73

# %%
# Out:
# /Users/whitney/.pyenv/versions/3.10.0/bin/python
# 3.10.0 (default, Apr  7 2022, 22:40:35) [Clang 12.0.5 (clang-1205.0.22.11)]
