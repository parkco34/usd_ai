# %%
# %pip -q install -U langchain langchain-community langchain-google-genai wikipedia google-generativeai

# %% [markdown]
# # Connect the Gemini API

# %%
import google.generativeai as genai
from google.colab import userdata

# Load the API key from Colab secrets
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# Configure the Gemini API
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# # Build a basic langchain agent

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import initialize_agent, AgentType

#Instantiate the Wikipedia tool
api_wrapper = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=1000)
wikipedia_tool = WikipediaQueryRun(api_wrapper=api_wrapper)

#Initialize the Gemini model, explicitly passing the API key and using a supported model
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash-latest", temperature=0, google_api_key=GOOGLE_API_KEY)

#Initialize the LangChain agent
agent = initialize_agent(
    tools=[wikipedia_tool],
    llm=llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-421/1470277984.py in <cell line: 0>()
#       2 from langchain_community.utilities import WikipediaAPIWrapper
#       3 from langchain_google_genai import ChatGoogleGenerativeAI
# ----> 4 from langchain.agents import initialize_agent, AgentType
#       5
#       6 #Instantiate the Wikipedia tool
#
# ImportError: cannot import name 'initialize_agent' from 'langchain.agents' (/usr/local/lib/python3.12/dist-packages/langchain/agents/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Run the agent

# %%
# Run the agent with a sample query
agent.run("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-421/591462411.py in <cell line: 0>()
#       1 # Run the agent with a sample query
# ----> 2 agent.run("What is the capital of France?")
#
# NameError: name 'agent' is not defined
